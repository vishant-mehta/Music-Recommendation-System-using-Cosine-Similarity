# %% [markdown]
# # Music recommender system

# %% [markdown]
# ### Importing required libraries

# %%
import numpy as np
import pandas as pd

# %%
from typing import List, Dict

# %%
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.metrics.pairwise import cosine_similarity

# %% [markdown]
# ### Dataset

# %%
songs = pd.read_csv('songdata.csv')

# %%
songs.head()
# Out:
#   artist                   song                                        link  \
# 0   ABBA  Ahe's My Kind Of Girl  /a/abba/ahes+my+kind+of+girl_20598417.html
# 1   ABBA       Andante, Andante       /a/abba/andante+andante_20002708.html
# 2   ABBA         As Good As New        /a/abba/as+good+as+new_20003033.html
# 3   ABBA                   Bang                  /a/abba/bang_20598415.html
# 4   ABBA       Bang-A-Boomerang      /a/abba/bang+a+boomerang_20002668.html
#
#                                                 text
# 0  Look at her face, it's a wonderful face  \nAnd...
# 1  Take it easy with me, please  \nTouch me gentl...
# 2  I'll never know why I had to go  \nWhy I had t...
# 3  Making somebody happy is a question of give an...
# 4  Making somebody happy is a question of give an...

# %% [markdown]
# Dataset being Big , we have taken random 1000 songs

# %%
songs = songs.sample(n=1000).drop('link', axis=1).reset_index(drop=True)

# %%
songs['text'] = songs['text'].str.replace(r'\n', '')

# %%
tfidf = TfidfVectorizer(analyzer='word', stop_words='english')

# %%
lyrics_matrix = tfidf.fit_transform(songs['text'])

# %%
cosine_similarities = cosine_similarity(lyrics_matrix)

# %% [markdown]
# Once we get the similarities, we'll store in a dictionary the names of the 50  most similar songs for each song in our dataset.

# %%
similarities = {}

# %%
for i in range(len(cosine_similarities)):
    similar_indices = cosine_similarities[i].argsort()[:-50:-1] 

    similarities[songs['song'].iloc[i]] = [(cosine_similarities[i][x], songs['song'][x], songs['artist'][x]) for x in similar_indices][1:]

# %% [markdown]
# We can use that similarity scores to access the most similar items and give a recommendation.

# %%
class ContentBasedRecommender:
    def __init__(self, matrix):
        self.matrix_similar = matrix

    def _print_message(self, song, recom_song):
        rec_items = len(recom_song)
        
        print(f'The {rec_items} recommended songs for {song} are:')
        for i in range(rec_items):
            print(f"Number {i+1}:")
            print(f"{recom_song[i][1]} by {recom_song[i][2]} with {round(recom_song[i][0], 3)} similarity score") 
            print("--------------------")
        
    def recommend(self, recommendation):
        song = recommendation['song']
        number_songs = recommendation['number_songs']
        recom_song = self.matrix_similar[song][:number_songs]
        self._print_message(song=song, recom_song=recom_song)

# %%
recommedations = ContentBasedRecommender(similarities)

# %%
songs
# Out:
#                  artist                                    song  \
# 0            Diana Ross                      Love Or Loneliness
# 1         Kirk Franklin                            Sweet Spirit
# 2          David Guetta                        Gettin' Over You
# 3        Counting Crows                             Dislocation
# 4     Steve Miller Band                      Key To The Highway
# 5        Spandau Ballet                          Cross The Line
# 6         Pet Shop Boys                          I Want A Lover
# 7       Whitney Houston                The Star Spangled Banner
# 8              Bee Gees                               Here I Am
# 9           David Bowie     It's Hard To Be A Saint In The City
# 10       Linda Ronstadt                  I'm A Fool To Want You
# 11      Alice In Chains                        Whatcha Gonna Do
# 12         Neil Diamond                            Gitchy Goomy
# 13          Roy Orbison           I've Been Loving You Too Long
# 14       Linda Ronstadt                            Falling Down
# 15       Jackson Browne                        I'll Do Anything
# 16            New Order                     Every Little Counts
# 17   Kris Kristofferson                       Lights Of Magdala
# 18         Ariel Rivera                       Wala Kang Katulad
# 19       Britney Spears                              Hot As Ice
# 20            Radiohead                              Decks Dark
# 21         Phil Collins                   If Leaving Me Is Easy
# 22                   U2                      All Because Of You
# 23            Offspring                           Out On Patrol
# 24         Cyndi Lauper                          Can't Blame Me
# 25          Nicki Minaj                      Hello Good Morning
# 26            Bob Dylan                   I Wanna Be Your Lover
# 27        Elvis Presley                        He'll Have To Go
# 28       Jennifer Lopez                              Louboutins
# 29       Spandau Ballet                             Big Feeling
# ..                  ...                                     ...
# 970         Deep Purple                             Bloodsucker
# 981  You said we'd light the firmament  You said ou...
# 982  When you get to the bottom  You go back to the...
# 983  Little yellow house sittin' on a hill  That is...
# 984  Justice to the left of you  Justice to the rig...
# 985  A broken heart, a pillow filled with tears  It...
# 986  Life isn't easy  Love never lasts  You just ca...
# 987  Trapping out the house with the boards on the ...
# 988  Be careful How you walk  These days are evil L...
# 989  My heart beats, wild and deep  Every thought i...
# 990  Had my lunch all alone  Waited for you to phon...
# 991  When I was small, and Christmas trees were tal...
# 992  There are no marks upon a man  That can say he...
# 993  It's in your eyes,  The love you hide away.  Y...
# 994  Left in the darkness  Here on your own  Woke u...
# 995  There was a moon and a street lamp  I didn't k...
# 996  Naitatte nanimo kawaranai tte iwareru kedo  Da...
# 997  I was walking by the river, I was asking mysel...
# 998  A perfect day, the sun is sinkin' low  As even...
# 999  Thank you for the lies, the lies you sold us  ...
#
# [1000 rows x 3 columns]

# %%
song_name=input("Choose any Song from the list: " )
song_number=int(input("Choose number of songs you want as recommended "))
# Out:
# Choose any Song from the list: Blood
# Choose number of songs you want as recommended 25

# %%
recommendation = {
    "song": song_name,
    "number_songs": song_number 
}

# %%
recommedations.recommend(recommendation)
# Out:
# The 25 recommended songs for Blood are:
# Number 1:
# Nothing But The Blood by Randy Travis with 0.302 similarity score
# --------------------
# Number 2:
# Muddy, Sam And Otis by Rod Stewart with 0.285 similarity score
# --------------------
# Number 3:
# Paths Of Glory by Faith No More with 0.247 similarity score
# --------------------
# Number 4:
# Bread And Blood by Air Supply with 0.207 similarity score
# --------------------
# Number 5:
# Long Time Gone by Allman Brothers Band with 0.199 similarity score
# --------------------
# Number 6:
# Right Is Right by Chaka Khan with 0.179 similarity score
# --------------------
# Number 7:
# Days Like These by Regine Velasquez with 0.16 similarity score
# --------------------
# Number 8:
# Move On by Bruno Mars with 0.132 similarity score
# --------------------
# Number 9:
# Material World by Tracy Chapman with 0.124 similarity score
# --------------------
# Number 10:
# I Got The Right Street by Chaka Khan with 0.124 similarity score
# --------------------
# Number 11:
# I'm A Fool To Want You by Linda Ronstadt with 0.117 similarity score
# --------------------
# Number 12:
# After The Fall by Journey with 0.115 similarity score
# --------------------
# Number 13:
# Kill On Command by Overkill with 0.105 similarity score
# --------------------
# Number 14:
# Could I Ever by Planetshakers with 0.099 similarity score
# --------------------
# Number 15:
# Shine by Richard Marx with 0.098 similarity score
# --------------------
# Number 16:
# Mistaken Identity by Donna Summer with 0.096 similarity score
# --------------------
# Number 17:
# Where Is The Love (with Black Eyed Peas) by Justin Timberlake with 0.094 similarity score
# --------------------
# Number 18:
# Hard On For Love by Nick Cave with 0.092 similarity score
# --------------------
# Number 19:
# Red Eye by Devo with 0.091 similarity score
# --------------------
# Number 20:
# Raindrops by Pitbull with 0.09 similarity score
# --------------------
# Number 21:
# Whatcha Gonna Do by Alice In Chains with 0.088 similarity score
# --------------------
# Number 22:
# Swamp by Talking Heads with 0.083 similarity score
# --------------------
# Number 23:
# SIX MORE MILES by Hank Williams with 0.082 similarity score
# --------------------
# Number 24:
# My Worst Fear by Rascal Flatts with 0.081 similarity score
# --------------------
# Number 25:
# I Could Sing Of Your Love Forever by Hillsong with 0.08 similarity score
# --------------------
